# %%
import ee
import geemap.foliumap as geemap

# %%
ee.Authenticate()
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=jrzH3kL1LKVAO7uHWbgLqfyL7nmV3lM79KFN0CedP1g&tc=F2j5An-CKDGhWLKdjhUitL281LOt0CYBagQBx9V34lI&cc=6vsQsBxgfyCu4XShihks4TgFnptqFNjE6cOlL7Lt_YU>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=jrzH3kL1LKVAO7uHWbgLqfyL7nmV3lM79KFN0CedP1g&tc=F2j5An-CKDGhWLKdjhUitL281LOt0CYBagQBx9V34lI&cc=6vsQsBxgfyCu4XShihks4TgFnptqFNjE6cOlL7Lt_YU</a></p>
#         <p>The authorization workflow will generate a code, which you should paste in the box below.</p>
# Enter verification code: 4/1AbUR2VNCuD1fdS64q1EwHjRqQDVB7U58pK56plFJyrvXsV2CWkmSYZtmP9Y
#
# Successfully saved authorization token.

# %%
ee.Initialize()

# %%
zone = ee.FeatureCollection("users/nachogbn/pnatural_23030")

# %%
m = geemap.Map()
m.centerObject(zone)
m.addLayer(zone)
m
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_019301858f933674fe29b244a011229e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_019301858f933674fe29b244a011229e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_019301858f933674fe29b244a011229e = L.map(
#                 &quot;map_019301858f933674fe29b244a011229e&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     eeInitialize: true,
#                     addGoogleMap: true,
#                     pluginLatlngpopup: false,
#                     pluginFullscreen: true,
#                     pluginDraw: true,
#                     DrawExport: false,
#                     pluginMinimap: false,
#                     pluginLayercontrol: false,
#                     locateControl: false,
#                     searchControl: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eace98ce09955cbda5eeac97c650748b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 30, &quot;maxZoom&quot;: 30, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_019301858f933674fe29b244a011229e);
#
#
#             var tile_layer_6944d5abb7edb5be6cd36590b52b6697 = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=m\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 22, &quot;maxZoom&quot;: 22, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_019301858f933674fe29b244a011229e);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_019301858f933674fe29b244a011229e);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems = new L.featureGroup().addTo(
#                 map_019301858f933674fe29b244a011229e
#             );
#             options.edit.featureGroup = drawnItems;
#             var draw_control_bc93f7ffda6e1ebc06a537ed23fa7fae = new L.Control.Draw(
#                 options
#             ).addTo( map_019301858f933674fe29b244a011229e );
#             map_019301858f933674fe29b244a011229e.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems.addLayer(layer);
#              });
#             map_019301858f933674fe29b244a011229e.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems.addLayer(e.layer);
#             });
#
#
#
#             L.Control.geocoder(
#                 {&quot;collapsed&quot;: true, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;}
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 map_019301858f933674fe29b244a011229e.setView(e.geocode.center, 11);
#             }).addTo(map_019301858f933674fe29b244a011229e);
#
#
#
#             map_019301858f933674fe29b244a011229e.fitBounds(
#                 [[20, 0], [20, 0]],
#                 {&quot;maxZoom&quot;: 2}
#             );
#
#
#             map_019301858f933674fe29b244a011229e.fitBounds(
#                 [[36.9133776896327, -3.6418240857705615], [37.25401295879082, -2.587480321389841]],
#                 {}
#             );
#
#
#             var tile_layer_b1f2aa20611c4ab64b7eb6a58b19f380 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/maps/82ee0e2b1bf2cbd1d6bdc6abaaf87d34-0082fb33f18f49d2ff67badb5aec9d35/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Googl

# %%
def get_NDSI(img):
    return img.addBands(img.normalizedDifference(["B4","B3"]).rename("NDSI"))

# %%
l7collection = (
    ee.ImageCollection('LANDSAT/LE07/C01/T1_SR')
    .filterBounds(zone)
    .filterDate('2008-01-01', '2018-01-01')
)

# %%
l7nvdi = l7collection.map(get_NDSI)

# %%
composite = l7nvdi.qualityMosaic('NDSI').clip(zone)

band = composite.select('NDSI ')

# %%
m2 = geemap.Map()

m2.centerObject(zone, zoom=10)

vis_params = {'min': 0, 'max': 1, 'palette': ['beb261', '8ffff9', '1cd810']}

m2.addLayer(band, vis_params, 'NDSI')

m2
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\ee\data.py:328, in _execute_cloud_call(call, num_retries)
#     327 try:
# --> 328   return call.execute(num_retries=num_retries)
#     329 except googleapiclient.errors.HttpError as e:
#
# File ~\anaconda3\lib\site-packages\googleapiclient\_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\googleapiclient\http.py:938, in HttpRequest.execute(self, http, num_retries)
#     937 if resp.status >= 300:
# --> 938     raise HttpError(resp, content, uri=self.uri)
#     939 return self.postproc(resp, content)
#
# HttpError: <HttpError 400 when requesting https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/maps?fields=name&alt=json returned "Image.select: Pattern 'NDSI ' did not match any bands.". Details: "Image.select: Pattern 'NDSI ' did not match any bands.">
#
# During handling of the above exception, another exception occurred:
#
# EEException                               Traceback (most recent call last)
# Cell In[14], line 7
#       3 m2.centerObject(zone, zoom=10)
#       5 vis_params = {'min': 0, 'max': 1, 'palette': ['beb261', '8ffff9', '1cd810']}
# ----> 7 m2.addLayer(band, vis_params, 'NDSI')
#       9 m2
#
# File ~\anaconda3\lib\site-packages\geemap\foliumap.py:276, in Map.add_layer(self, ee_object, vis_params, name, shown, opacity, **kwargs)
#     271     elif not isinstance(vis_params["palette"], list):
#     272         raise ValueError(
#     273             "The palette must be a list of colors or a string or a Box object."
#     274         )
# --> 276 map_id_dict = ee.Image(image).getMapId(vis_params)
#     278 # if a layer starts with a number, add "Layer" to name.
#     279 if name[0].isdigit():
#
# File ~\anaconda3\lib\site-packages\ee\image.py:132, in Image.getMapId(self, vis_params)
#     130 vis_image, request = self._apply_visualization(vis_params)
#     131 request['image'] = vis_image
# --> 132 response = data.getMapId(request)
#     133 response['image'] = self
#     134 return response
#
# File ~\anaconda3\lib\site-packages\ee\data.py:593, in getMapId(params)
#     591 if workload_tag:
#     592   queryParams['workloadTag'] = workload_tag
# --> 593 result = _execute_cloud_call(
#     594     _get_cloud_api_resource().projects().maps().create(
#     595         parent=_get_projects_path(), **queryParams))
#     596 map_name = result['name']
#     597 url_format = '%s/%s/%s/tiles/{z}/{x}/{y}' % (
#     598     _tile_base_url, _cloud_api_utils.VERSION, map_name)
#
# File ~\anaconda3\lib\site-packages\ee\data.py:330, in _execute_cloud_call(call, num_retries)
#     328   return call.execute(num_retries=num_retries)
#     329 except googleapiclient.errors.HttpError as e:
# --> 330   raise _translate_cloud_exception(e)
#
# EEException: Image.select: Pattern 'NDSI ' did not match any bands.

# %%
bands = []

years = range(2008, 2018)

for year in years:
    l7collection = (
    ee.ImageCollection('LANDSAT/LE07/C01/T1_SR')
    .filterBounds(zone)
    .filterDate(str(year) + '-01-01', str(year) + '-12-31')
    )
    
    l7nvdi = l7collection.map(get_NDVI)
    
    composite = l7nvdi.qualityMosaic('NDSI').clip(zone)

    band = composite.select('NDSI')
    
    bands.append(band)

# %%
m3 = geemap.Map()

m3.centerObject(zone, zoom=10)

vis_params = {'min': 0, 'max': 1, 'palette': ['beb261', '8ffff9', '1cd810']}

for position, band in enumerate (bands):
    m2.addLayer(band, vis_params, 'NDSI_' + str(2000 + position))

m3
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d8e515123ffb98d54a089b2c8232a402 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d8e515123ffb98d54a089b2c8232a402&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d8e515123ffb98d54a089b2c8232a402 = L.map(
#                 &quot;map_d8e515123ffb98d54a089b2c8232a402&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     eeInitialize: true,
#                     addGoogleMap: true,
#                     pluginLatlngpopup: false,
#                     pluginFullscreen: true,
#                     pluginDraw: true,
#                     DrawExport: false,
#                     pluginMinimap: false,
#                     pluginLayercontrol: false,
#                     locateControl: false,
#                     searchControl: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a8ab923e71818ba51f357b2389ddea51 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 30, &quot;maxZoom&quot;: 30, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d8e515123ffb98d54a089b2c8232a402);
#
#
#             var tile_layer_71f4f293d2794a97af4ed935fea802e5 = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=m\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 22, &quot;maxZoom&quot;: 22, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d8e515123ffb98d54a089b2c8232a402);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_d8e515123ffb98d54a089b2c8232a402);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems = new L.featureGroup().addTo(
#                 map_d8e515123ffb98d54a089b2c8232a402
#             );
#             options.edit.featureGroup = drawnItems;
#             var draw_control_0c966e99ab8d649c5c2848b546312324 = new L.Control.Draw(
#                 options
#             ).addTo( map_d8e515123ffb98d54a089b2c8232a402 );
#             map_d8e515123ffb98d54a089b2c8232a402.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems.addLayer(layer);
#              });
#             map_d8e515123ffb98d54a089b2c8232a402.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems.addLayer(e.layer);
#             });
#
#
#
#             L.Control.geocoder(
#                 {&quot;collapsed&quot;: true, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;}
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 map_d8e515123ffb98d54a089b2c8232a402.setView(e.geocode.center, 11);
#             }).addTo(map_d8e515123ffb98d54a089b2c8232a402);
#
#
#
#             map_d8e515123ffb98d54a089b2c8232a402.fitBounds(
#                 [[20, 0], [20, 0]],
#                 {&quot;maxZoom&quot;: 2}
#             );
#
#
#             map_d8e515123ffb98d54a089b2c8232a402.fitBounds(
#                 [[37.0670734002369, -3.138313479497802], [37.0670734002369, -3.138313479497802]],
#                 {&quot;maxZoom&quot;: 10}
#             );
#
#
#             var layer_control_7b7d990e7610f246d34279c40f53c08f = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_a8ab923e71818ba51f357b2389ddea51,
#                 },
#                 overlays :  {
#                     &quot;Google Maps&quot; : tile_laye

# %%
lat = 37.0311
lon = -3.3259
point = ee.Geometry.Point([lon, lat])

# %%
#Con esto estamos juntando todas la bandas en una sola imagen porque es como lo necesita el programa para poder ver la tendencia que tiene el NDVI a lo largo de los años. Lo que hace es mulitplicas los valores para tener un valor entre -1 y 1 para ver si sube o baja
stack_collection = ee.ImageCollection(bands)
ndvis = stack_collection.toBands()

# %%
ndvi_trend = ndvis.reduce(ee.Reducer.kendallsCorrelation())
tau = ndvi_trend.select('tau')

# %%
m2 = geemap.Map()

m2.centerObject(zone, zoom=10)

vis_params = {'min': -1, 'max': 1, 'palette': ['red', 'orange', 'yellow', 'green']}

m2.addLayer(tau, vis_params, 'Mann-Kendal')

m2
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_93cff72119b725abd1fc58696defb253 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_93cff72119b725abd1fc58696defb253&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_93cff72119b725abd1fc58696defb253 = L.map(
#                 &quot;map_93cff72119b725abd1fc58696defb253&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     eeInitialize: true,
#                     addGoogleMap: true,
#                     pluginLatlngpopup: false,
#                     pluginFullscreen: true,
#                     pluginDraw: true,
#                     DrawExport: false,
#                     pluginMinimap: false,
#                     pluginLayercontrol: false,
#                     locateControl: false,
#                     searchControl: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1de31144fe34dc8dab0a95625cc81bf5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 30, &quot;maxZoom&quot;: 30, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_93cff72119b725abd1fc58696defb253);
#
#
#             var tile_layer_71f4f293d2794a97af4ed935fea802e5 = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=m\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 22, &quot;maxZoom&quot;: 22, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_93cff72119b725abd1fc58696defb253);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_93cff72119b725abd1fc58696defb253);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems = new L.featureGroup().addTo(
#                 map_93cff72119b725abd1fc58696defb253
#             );
#             options.edit.featureGroup = drawnItems;
#             var draw_control_245b885eea68971ae5e6bd3ba873744f = new L.Control.Draw(
#                 options
#             ).addTo( map_93cff72119b725abd1fc58696defb253 );
#             map_93cff72119b725abd1fc58696defb253.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems.addLayer(layer);
#              });
#             map_93cff72119b725abd1fc58696defb253.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems.addLayer(e.layer);
#             });
#
#
#
#             L.Control.geocoder(
#                 {&quot;collapsed&quot;: true, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;}
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 map_93cff72119b725abd1fc58696defb253.setView(e.geocode.center, 11);
#             }).addTo(map_93cff72119b725abd1fc58696defb253);
#
#
#
#             map_93cff72119b725abd1fc58696defb253.fitBounds(
#                 [[20, 0], [20, 0]],
#                 {&quot;maxZoom&quot;: 2}
#             );
#
#
#             map_93cff72119b725abd1fc58696defb253.fitBounds(
#                 [[37.0670734002369, -3.138313479497802], [37.0670734002369, -3.138313479497802]],
#                 {&quot;maxZoom&quot;: 10}
#             );
#
#
#             var tile_layer_9ca144c6827f66aa6090d3d0827b898e = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/maps/c3962f220ab256b20cab6b2e475922e6-14fabad752e9395faa3c0ecda6c1f7a4/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attributi
